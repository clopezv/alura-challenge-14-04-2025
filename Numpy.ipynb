# %% [markdown]
# <a href="https://colab.research.google.com/github/clopezv/alura-challenge-14-04-2025/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data = np.genfromtxt('/content/manzanas.csv', delimiter=',', dtype=None, encoding=None)
print(data)

# %%
#12 * 7 + 3 = 87
import numpy as np
np.arange(1,88,1)

data = np.genfromtxt('/content/manzanas.csv', delimiter=',', usecols=np.arange(1,88,1), dtype=None, encoding=None)
print(data)
data.ndim
data.shape
print(f'Dimensiones del array {data.ndim}') #Muestra la cantidad de dimensiones del array
print(f'Dimensiones del array {data.shape}') #Muestra la cantidad de filas y columnas del array 6 filas y 87 columnas
print(f'Cantidad de filas {data.shape[0]}') #Muestra la cantidad de filas del array 6 filas
print(f'Cantidad de columnas {data.shape[1]}') #Muestra la cantidad de columnas del array 87 columnas
print(f'Cantidad de elementos {data.size}') #Muestra la cantidad de elementos del array 522 columnas
print(f'Cantidad de bytes {data.nbytes}') #Muestra la cantidad de bytes del array 522 columnas
datos_transpuestos = data.transpose()
print(f'Datos transpuestos {datos_transpuestos}') #Muestra el tipo de datos del array

fechas = datos_transpuestos[:,0]
print(f'Fechas {fechas}') #Muestra las fechas solamente

precios = datos_transpuestos[:,1:]
print(f'Precios {precios}') #Muestra los precios solamente
# Out:
# [[  1.2013   2.2013   3.2013   4.2013   5.2013   6.2013   7.2013   8.2013
#     9.2013  10.2013  11.2013  12.2013   1.2014   2.2014   3.2014   4.2014
#     5.2014   6.2014   7.2014   8.2014   9.2014  10.2014  11.2014  12.2014
#     1.2015   2.2015   3.2015   4.2015   5.2015   6.2015   7.2015   8.2015
#     9.2015  10.2015  11.2015  12.2015   1.2016   2.2016   3.2016   4.2016
#     5.2016   6.2016   7.2016   8.2016   9.2016  10.2016  11.2016  12.2016
#     1.2017   2.2017   3.2017   4.2017   5.2017   6.2017   7.2017   8.2017
#     9.2017  10.2017  11.2017  12.2017   1.2018   2.2018   3.2018   4.2018
#     5.2018   6.2018   7.2018   8.2018   9.2018  10.2018  11.2018  12.2018
#     1.2019   2.2019   3.2019   4.2019   5.2019   6.2019   7.2019   8.2019
#     9.2019  10.2019  11.2019  12.2019   1.202    2.202    3.202 ]
#  [ 79.72    81.08    79.68    79.8     80.63    80.8     80.28    78.99
#    76.77    76.09    76.36    77.16    77.5     79.03    80.28    80.05
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
np.arange(1,88,1)

data = np.genfromtxt('/content/manzanas.csv', delimiter=',', usecols=np.arange(1,88,1), dtype=None, encoding=None)
fechas = datos_transpuestos[:,0]
precios = datos_transpuestos[:,1:]
#plt.plot(fechas, precios)
#plt.show()
fechas = np.arange(1,88,1)
plt.plot(fechas, precios[:,0])

#Moscu = precios[:,0]
Kaliningrado = precios[:,1]
#Petersburgo = precios[:,2]
#Krasnodar = precios[:,3]
#Kaliningrado = precios[:,4]
plt.plot(fechas, Kaliningrado)
plt.show()

# %% [markdown]
# COMPARACION DE ARRAYS

# %%
  Moscu = precios[:,0]
  Moscu.shape
# Out:
# (87,)

# %%
import numpy as np
import matplotlib.pyplot as plt
np.arange(1,88,1)

data = np.genfromtxt('/content/manzanas.csv', delimiter=',', usecols=np.arange(1,88,1), dtype=None, encoding=None)
moscu_1 = Moscu[0:12]
moscu_2 = Moscu[12:24]
moscu_3 = Moscu[24:36]
moscu_4 = Moscu[36:48]
plt.plot(np.arange(1,13,1), moscu_1)
plt.plot(np.arange(1,13,1), moscu_2)
plt.plot(np.arange(1,13,1), moscu_3)
plt.plot(np.arange(1,13,1), moscu_4)
plt.legend(['2013','2014','2015','2016'])
plt.show()

# %%
np.array_equal(moscu_1, moscu_2)
# Out:
# False

# %%
np.allclose(moscu_1, moscu_2,2)
# Out:
# True

# %% [markdown]
# TRATAMIENTO NaN

# %%
import numpy as np
#import matplotlib.pyplot as plt
np.arange(1,88,1)

data = np.genfromtxt('/content/manzanas.csv', delimiter=',', usecols=np.arange(1,88,1), dtype=None, encoding=None)
datos_transpuestos = data.transpose()
fechas = datos_transpuestos[:,0]
precios = datos_transpuestos[:,1:]
Kaliningrado = precios[:,1]

moscu_1 = Moscu[0:12]
moscu_2 = Moscu[12:24]
moscu_3 = Moscu[24:36]
moscu_4 = Moscu[36:48]
np.mean(Moscu) #Promedio

np.isnan(Kaliningrado) #Verifica si hay valores nulos
np.sum(np.isnan(Kaliningrado)) #Detectar si hay NaN
Kaliningrado[4] = (Kaliningrado[3] + Kaliningrado[5])/2 #Sacar un promedio entre el valor anterior al Nan y al siguiente
plt.plot(fechas, Kaliningrado)
plt.show()

# %%
np.mean(Kaliningrado) #Promedio
# Out:
# np.float64(74.55942528735632)

# %%
np.isnan(Kaliningrado) #Verifica si hay valores nulos
np.sum(np.isnan(Kaliningrado)) #Detectar si hay NaN
Kaliningrado[4] = (Kaliningrado[3] + Kaliningrado[5])/2 #Sacar un promedio entre el valor anterior al Nan y al siguiente
plt.plot(fechas, Kaliningrado)
plt.show()

# %%
np.sum(np.isnan(Kaliningrado)) #Detectar si hay NaN
Kaliningrado[4] = (Kaliningrado[3] + Kaliningrado[5])/2 #Sacar un promedio entre el valor anterior al Nan y al siguiente
plt.plot(fechas, Kaliningrado)
plt.show()
