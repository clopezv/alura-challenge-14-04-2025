# %% [markdown]
# <a href="https://colab.research.google.com/github/clopezv/alura-challenge-14-04-2025/blob/main/Pandas_I_O_clv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Aula 1 - Leyendo archivos csv**
#
# **Importando archivos csv**

# %%
import pandas as pd

url = "/content/superstore_data.csv"
datos = pd.read_csv(url, sep=',')
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
datos_punto_coma = pd.read_csv('/content/superstore_data_punto_coma.csv', sep=';')
datos_punto_coma.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
datos_punto_coma = pd.read_csv('superstore_data.csv', sep=',', nrows = 10, usecols=['Id', 'Year_Birth', 'Income'])
datos_punto_coma.head(5)
# Out:
#       Id  Year_Birth  Income
# 0   1826        1970   84835
# 1      1        1961   57091
# 2  10476        1958   67267
# 3   1386        1967   32474
# 4   5371        1989   21474

# %%
datos_punto_coma = pd.read_csv('superstore_data.csv', sep=',', nrows = 10, usecols=['Id', 'Year_Birth', 'Income'])
datos_punto_coma.head(5)
# Out:
#       Id  Year_Birth  Income
# 0   1826        1970   84835
# 1      1        1961   57091
# 2  10476        1958   67267
# 3   1386        1967   32474
# 4   5371        1989   21474

# %%
datos_punto_coma = pd.read_csv('superstore_data.csv', sep=',', nrows = 10, usecols=[0, 1, 4])
datos_punto_coma.head(5)
# Out:
#       Id  Year_Birth  Income
# 0   1826        1970   84835
# 1      1        1961   57091
# 2  10476        1958   67267
# 3   1386        1967   32474
# 4   5371        1989   21474

# %%
datos_punto_coma.to_csv('clientes_mercado.csv', sep=',', index=False)

# %%
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#       Id  Year_Birth  Income
# 0   1826        1970   84835
# 1      1        1961   57091
# 2  10476        1958   67267
# 3   1386        1967   32474
# 4   5371        1989   21474
# 5   7348        1958   71691
# 6   4073        1954   63564
# 7   1991        1967   44931
# 8   4047        1954   65324
# 9   9477        1954   65324

# %% [markdown]
# ### **Aula2 - Leyendo archivos Excel**
#
# **Importando archivos excel**

# %%
import pandas as pd
archivo = '/content/emisiones_CO2.xlsx'
datos_co2 = pd.read_excel(archivo)
datos_co2.head(5)
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
pd.ExcelFile(archivo).sheet_names #Muestra las hojas que tiene el excel
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# ###**Párametros de la función read_excel**

# %%
percapita = pd.read_excel(archivo, sheet_name='emisiones_percapita') #Selecciona la hoja que tiene el excel
percapita.head(5)
percapita.tail()
percapita.sample(5)
# Out:
#           País ISO 3166-1 alpha-3   Año     Total  Carbón    Aceite  Gas  \
# 5961     Benín                BEN  1999  215352.0     0.0  215352.0  0.0
# 58640   Uganda                UGA  1910       NaN     NaN       NaN  NaN
# 45185  Camerún                CMR  1783       NaN     NaN       NaN  NaN
# 34442     Malí                MLI  1920       NaN     NaN       NaN  NaN
# 60184  Uruguay                URY  1822       NaN     NaN       NaN  NaN
#
#        Cemento  Quema  Otros
# 5961       0.0    0.0    NaN
# 58640      NaN    NaN    NaN
# 45185      NaN    NaN    NaN
# 34442      NaN    NaN    NaN
# 60184      NaN    NaN    NaN

# %%
percapita = pd.read_excel(archivo, sheet_name='fuentes') #Selecciona la hoja que tiene el excel
percapita.head(5)
percapita.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
# ...

# %%
intervalo = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols='A:D') #Selecciona la hoja que tiene el excel y despliega 4 columnas

# %%
intervalo.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750    0.0
# 1  Afganistán                AFG  1751    0.0
# 2  Afganistán                AFG  1752    0.0
# 3  Afganistán                AFG  1753    0.0
# 4  Afganistán                AFG  1754    0.0

# %%
intervalo_2 = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols='A:D', nrows= 10) #Selecciona la hoja que tiene el excel y despliega 4 columnas

# %%
intervalo_2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %%
intervalo.to_excel('co2_percapita.xlsx', index=False) #Exportar a Excel

# %%
pd.read_excel('co2_percapita.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
sheet_id ="12QYoW3qmRmBgJ7L9SYEvyO2Uy8dMSCyUJWUlrm3sKQM"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet"
#https://docs.google.com/spreadsheets/d/12QYoW3qmRmBgJ7L9SYEvyO2Uy8dMSCyUJWUlrm3sKQM/edit?usp=sharing

# %%
datos_co2_sheets = pd.read_csv(url)

# %%
datos_co2_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36.096.739.276  14.506.973.805
# 63100      Global                WLD  2018  36.826.506.600  14.746.830.688
# 63101      Global                WLD  2019  37.082.558.969  14.725.978.025
# 63102      Global                WLD  2020  35.264.085.734  14.174.564.010
# 63103      Global                WLD  2021  37.123.850.352  14.979.598.083
#
# ...

# %%
sheet_id ="12QYoW3qmRmBgJ7L9SYEvyO2Uy8dMSCyUJWUlrm3sKQM"
sheet_name = "emisiones_percapita"
url_percapita = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
percapita_sheets = pd.read_csv(url_percapita)
percapita_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 0      Afganistán                AFG  1750        NaN        NaN        NaN
# 1      Afganistán                AFG  1751        NaN        NaN        NaN
# 2      Afganistán                AFG  1752        NaN        NaN        NaN
# 3      Afganistán                AFG  1753        NaN        NaN        NaN
# 4      Afganistán                AFG  1754        NaN        NaN        NaN
# ...           ...                ...   ...        ...        ...        ...
# 63099      Global                WLD  2017  4.749.682  1.908.857  1.610.910
# 63100      Global                WLD  2018  4.792.753  1.919.213  1.596.350
# 63101      Global                WLD  2019  4.775.633  1.896.468  1.589.920
# 63102      Global                WLD  2020  4.497.423  1.807.760  1.427.353
# 63103      Global                WLD  2021  4.693.699  1.893.923  1.496.614
#
#              Gas  Cemento   Quema   Otros
# ...

# %%
sheet_id ="12QYoW3qmRmBgJ7L9SYEvyO2Uy8dMSCyUJWUlrm3sKQM"
sheet_name = "fuentes"
url_fuentes = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
fuentes_sheets = pd.read_csv(url_fuentes)
fuentes_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año  \
# 0      Afganistán                AFG  1750
# 1      Afganistán                AFG  1751
# 2      Afganistán                AFG  1752
# 3      Afganistán                AFG  1753
# 4      Afganistán                AFG  1754
# ...           ...                ...   ...
# 63099      Global                WLD  2017
# 63100      Global                WLD  2018
# 63101      Global                WLD  2019
# 63102      Global                WLD  2020
# 63103      Global                WLD  2021
#
#                                       Total             Carbón  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...

# %% [markdown]
# ###**Aula3 - Leyendo archivos JSON**
# Importando archivos JSON

# %%
import pandas as pd
datos_pacientes = pd.read_json('/content/pacientes.json')
datos_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %%
datos_pacientes_2 = pd.read_json('/content/pacientes_2.json')
datos_pacientes_2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %%
df_norzmalizado = pd.json_normalize(datos_pacientes_2['Pacientes']) #Esta funcion es para mostrar los diccionario que trae el archivo
df_norzmalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %%
datos = {'Análisis': 'Principales indicadores de enfermedad cardíaca', 'Año': 2020, 'Numero_Pacientes':3}

# %%
df = pd.json_normalize(datos)
df
# Out:
#                                          Análisis   Año  Numero_Pacientes
# 0  Principales indicadores de enfermedad cardíaca  2020                 3

# %%
json_lista = [
    { 'ID': '01', 'Intervalo_edad': '55-59', 'Sexo_biologico': 'femenino'},
    { 'ID': '02', 'Intervalo_edad': '80 ó +', 'Sexo_biologico': 'femenino'}
]

# %%
pd.json_normalize(json_lista)
# Out:
#    ID Intervalo_edad Sexo_biologico
# 0  01          55-59       femenino
# 1  02         80 ó +       femenino

# %%
json_obj = {
    'ID': '01',
    'Intervalo_edad': '55-59',
    'Sexo_biologico': 'Femenino',
    'Salud': {'Dificultad_caminar': 'No',
              'Actividad_fisica': 'Sí',
              'IMC': 16.6,
              'Enfermedad_cardiaca': 'No',
          }
      }

# %%
pd.json_normalize(json_obj)
# Out:
#    ID Intervalo_edad Sexo_biologico Salud.Dificultad_caminar  \
# 0  01          55-59       Femenino                       No
#
#   Salud.Actividad_fisica  Salud.IMC Salud.Enfermedad_cardiaca
# 0                     Sí       16.6                        No

# %%
json_list = [
    {
    'ID': '01',
    'Intervalo_edad': '55-59',
    'Sexo_biologico': 'Femenino',
    'Salud': {'Dificultad_caminar': 'No',
              'Actividad_fisica': 'Sí',
              'IMC': 16.6,
              'Enfermedad_cardiaca': 'No',
          }
      },
      {
          'ID': '02',
          'Intervalo_edad': '80 ó +',
          'Sexo_biologico': 'Femenino',
          'Salud': {'Dificultad_caminar': 'No',
                    'Actividad_fisica': 'Sí',
                    'IMC': 20.34,
                    'Enfermedad_cardiaca': 'Sí'}
       }
       ]

# %%
pd.json_normalize(json_list)
# Out:
#    ID Intervalo_edad Sexo_biologico Salud.Dificultad_caminar  \
# 0  01          55-59       Femenino                       No
# 1  02         80 ó +       Femenino                       No
#
#   Salud.Actividad_fisica  Salud.IMC Salud.Enfermedad_cardiaca
# 0                     Sí      16.60                        No
# 1                     Sí      20.34                        Sí

# %%
datos_dict = {
  "Investigación": "Indicadores clave de enfermedades cardíacas",
  "Año": 2020,
  "Pacientes": [
    {
     "ID": "01",
      "Rango_edad": "55-59",
      "Sexo_biologico": "Mujer",
      "Raza": "Blanca",
      "IMC": 16.6,
      "Fumador": "Sí",
      "Consumo_alcohol": "No",
      "Salud_física": 3,
      "Salud_mental": 30,
      "Dificultad_caminar": "No",
      "Actividad_física": "Sí",
      "Salud_general": "Muy buena",
      "Horas_sueño": 5,
      "Problemas_salud": [
        "Diabetes",
        "Asma",
        "Cancer_piel"
      ]
    },
    {
      "ID": "02",
      "Rango_edad": "80 ó +",
      "Sexo_biologico": "Mujer",
      "Raza": "Blanca",
      "IMC": 20.34,
      "Fumador": "No",
      "Consumo_alcohol": "No",
      "Salud_física": 0,
      "Salud_mental": 0,
      "Dificultad_caminar": "No",
      "Actividad_física": "Sí",
      "Salud_general": "Muy buena",
      "Horas_sueño": 7,
      "Problemas_salud": [
        "AVC"
      ]
    },
    {
      "ID": "03",
      "Rango_edad": "65-69",
      "Sexo_biologico": "Masculino",
      "Raza": "Blanca",
      "IMC": 26.58,
      "Fumador": "Sí",
      "Consumo_alcohol": "No",
      "Salud_física": 20,
      "Salud_mental": 30,
      "Dificultad_caminar": "No",
      "Actividad_física": "Sí",
      "Salud_general": "Muy buena",
      "Horas_sueño": 8,
      "Problemas_salud": [
        "Diabetes",
        "Asma"
      ]
    }
  ]
}

# %%
pd.json_normalize(datos_dict)
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  [{'ID': '01', 'Rango_edad': '55-59', 'Sexo_bio...

# %%
pd.json_normalize(datos_dict['Pacientes'])
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %%
pd.json_normalize(datos_dict, record_path=['Pacientes'])
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %%
pd.json_normalize(
    datos_dict,
    record_path =['Pacientes'],
    meta=['Investigación', 'Año']
)
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud  \
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]
#
#                                  Investigación   Año
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# ...

# %%
df_norzmalizado.to_json('historico_pacientes_normalizado.json') # Guardar el resultado en un archivo json

# %%
pd.read_json('historico_pacientes_normalizado.json')
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]
